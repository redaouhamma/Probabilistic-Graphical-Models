# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import math

# %%
data = pd.read_csv('classification_data_HWK1/classificationA.train',sep="\t", names=["a","b","c"])

# %% [markdown]
# ### LDA

# %%
pi=data["c"].mean()
mu_0=(data[data["c"]==0][["a","b"]].mean())
mu_1=(data[data["c"]==1][["a","b"]].mean())
sigma=data[["a","b"]].cov().multiply((data.size-1)/data.size)
# Out:
#           a         b
# a  9.432992 -3.333791
# b -3.333791  1.307870

# %%
sns.lmplot( x='a', y='b', data = data, fit_reg=False, hue='c', legend=False)
A=np.linalg.inv(sigma)
e_1=np.dot(A,np.subtract(mu_0,mu_1))
alpha=-math.log2(pi/(1-pi))+0.5*np.dot(mu_0,np.dot(A,mu_0))-0.5*np.dot(mu_1,np.dot(A,mu_1))
def line(x):
    return -(e_1[0]/e_1[1])*x + alpha/e_1[1]
xRange = ( data['a'].min(), data['a'].max() )
plt.plot( np.arange( *xRange ),line(np.arange( *xRange)), linestyle='solid', color='b')

# %% [markdown]
# ### Logistic Regression

# %%
data['d'] = pd.Series(np.ones(data.size))
X = data[["a","b","d"]]

def sigmoid(w):
    return 1/(1+np.exp(-np.dot(X,w)))
def S(w):
    return np.diag(np.multiply(sigmoid(w),sigmoid(-w)))
# def grad(w):
#     grad=np.dot(data["c"]-sigmoid(w),X)
#     return grad
def hess(w):
    hess=np.dot(np.transpose(X),np.dot(S(w),X))
    return np.linalg.pinv(hess)
def z(w):
    return np.dot(X,w)+np.dot(np.linalg.pinv(S(w)),data['c']-sigmoid(w))

# %%
w_new=np.ones(3)*100
w=np.random.rand(3)
cpt=0
while(np.linalg.norm(w-w_new)>1e-3):
    tmp=w_new
    w_new=np.dot(hess(w),np.dot(np.dot(S(w),z(w)),X))
    w=tmp
    cpt+=1
print(w)
print(w_new)
print(cpt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-8d0523c9ec48> in <module>()
#       4 while(np.linalg.norm(w-w_new)>1e-3):
#       5     tmp=w_new
# ----> 6     w_new=np.dot(hess(w),np.dot(np.dot(S(w),z(w)),X))
#       7     w=tmp
#       8     cpt+=1
#
# <ipython-input-57-3d917fcf1e80> in z(w)
#      13     return np.linalg.pinv(hess)
#      14 def z(w):
# ---> 15     return np.dot(X,w)+np.dot(np.linalg.pinv(S(w)),data['c']-sigmoid(w))
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond)
#    1722         return wrap(res)
#    1723     a = a.conjugate()
# -> 1724     u, s, vt = svd(a, full_matrices=False)
#    1725
#    1726     # discard small singular values
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1442
#    1443         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1444         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1445         u = u.astype(result_t, copy=False)
#    1446         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
sns.lmplot( x='a', y='b', data = data, fit_reg=False, hue='c', legend=False)
print(w[2]/w[1])
def logline(x):
    return -(w[0]/w[1])*x - w[2]/w[1]

plt.plot( np.arange( *xRange ),logline(np.arange( *xRange)), linestyle='solid', color='b')
# Out:
# 1.3523690212454456

# %% [markdown]
# ### Linear Regression

# %%
beta = np.dot(np.dot(X,np.linalg.inv(np.dot(X.T,X))).T,data[["c"]])
s=np.linalg.norm(data[['c']]-np.dot(data[["a","b","d"]],beta))/data.size

sns.lmplot( x='a', y='b', data = data, fit_reg=False, hue='c')

a=-beta[0]/beta[1]
b=-(beta[2]-1+np.sqrt(-s*math.log2(math.pi*s/2)))/beta[1]
def line(x):
    return a*x + b

plt.plot(np.arange(-9,9),line(np.arange(-9,9)), linestyle='solid', color='red')

# %% [markdown]
# ### QDA

# %%
import sympy
data[["a","b"]].cov().multiply((data.size-1)/data.size)
sigma0 = np.linalg.inv(data[data['c']==0][ [ "a", "b" ] ].cov().multiply( ( data.size - 1 ) / data.size ))
sigma1 = np.linalg.inv(data[data['c']==1][ [ "a", "b" ] ].cov().multiply( ( data.size - 1 ) / data.size ))
sigma  = -sigma0+sigma1
a = sigma[0,0]
c = sigma[1,1]
b = sigma[0,1]+sigma[1,0]
d,e = 2*np.dot(sigma0,mu_0) - 2*np.dot(sigma1,mu_1)
f = np.dot(np.dot(sigma1,mu_1),mu_1)-np.dot(np.dot(sigma0,mu_0),mu_0)-2*np.log((pi*np.linalg.det(sigma1))/((1-pi)*np.linalg.det(sigma0)))

# %%
yRange = ( data['b'].min()*3, data['b'].max()*3 )

x = np.linspace(xRange[0]*2, xRange[1] *2, 400)
y = np.linspace(*yRange, 400)
x, y = np.meshgrid(x, y)
def axes():
    plt.axhline(0, alpha=.1)
    plt.axvline(0, alpha=.1)

sns.lmplot( x='a', y='b', data = data, fit_reg=False, hue='c')
plt.contour(x, y,(a*x**2 + b*x*y + c*y**2 + d*x + e*y + f), [0], colors='k')
